# %%
import matplotlib.pyplot as plt
import io
from PIL import Image, ImageChops

white = (255, 255, 255, 255)

def latex_to_img(tex):
    # buf = io.BytesIO()
    plt.rc('text', usetex=True)
    plt.rc('font', family='serif')
    plt.axis('off')
    plt.text(0.05, 0.5, f'${tex}$', size=40)
    plt.savefig('output' format='png')
    plt.close()

#     im = Image.open(buf)
#     bg = Image.new(im.mode, im.size, white)
#     diff = ImageChops.difference(im, bg)
#     diff = ImageChops.add(diff, diff, 2.0, -100)
#     bbox = diff.getbbox()
    # return im.crop(bbox)

latex_to_img(r'\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)').save('output.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 23>()
#      16 #     im = Image.open(buf)
#      17 #     bg = Image.new(im.mode, im.size, white)
#      18 #     diff = ImageChops.difference(im, bg)
#      19 #     diff = ImageChops.add(diff, diff, 2.0, -100)
#      20 #     bbox = diff.getbbox()
#      21     return im.crop(bbox)
# ---> 23 latex_to_img(r'\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)').save('output.png')
#
# Input In [5], in latex_to_img(tex)
#      11     plt.axis('off')
#      12     plt.text(0.05, 0.5, f'${tex}$', size=40)
# ---> 13     plt.savefig(buf, format='png')
#      14     plt.close()
#      16 #     im = Image.open(buf)
#      17 #     bg = Image.new(im.mode, im.size, white)
# ...

# %%
import matplotlib.pyplot as plt

def latex_to_img(tex, name):
    plt.rcParams.update({
        "text.usetex": True,
        "font.family": "Helvetica",
        "figure.figsize": [30,2]
    })
    plt.axis('off')
    plt.text(0, 0.2, eq, size=60)
    plt.savefig(name)
    plt.show()

eqs = {
    'objective.png': r'$\sum^{S,T,J}_{s,t,j} \left( EV^2_{s,t,j} \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)$',
    'bioc_predicted_v_calculated.png': r'$E_{s,t,j}*EC = EB_{s,t,j}$',
    'diffc_biomass_variance.png': r'$EB_{s,t,j}-\sum^K_k \left( es_k*b_{t,j,k} \right) = EV_{s,t,j}$',
    'dbc_nonstationary.png': r'$b_{t,j,k} + \frac{\Delta t}{2}(g_{t,j,k}+g_{t+1,j,k}) + cvf_{t,j,k} - cvt_{t,j,k} = b_{t+1,j,k}$',
    'dbc_stationary.png': r'$b_{t,j,k} - \sum^{K,S}_{k,s} \left( es_{k,s}*cvf_{t,j,k} \right) + \sum^{K,S}_{k,s} \left( es_{k,s}*cvt_{t,j,k} \right) = b_{t+1,j,k}$',
    'cvc_transitions.png': r'$cvt_{t,j,k} \le bcv*b_{t,j,k} + cvmin$',
    'dcc_concentrations.png': r'$c_{t,j,i} + \frac{\Delta t}{2} \sum^K_k \left( n_{i,k}(g_{t,j,k}+g_{t+1,j,k}) \right) = c_{t+1,j,i}$',
    'heuns_method.png': r"$y_{t+1} = y_t + \frac{1}{2}*\Delta t*(y'_t+y'_{t+1})$"
}
for filename, eq in eqs.items():
    latex_to_img(eq, name=filename)

# %%
from sympy import Matrix, print_latex

X = Matrix([1,2,3])
print_latex(X)
# Out:
# \left[\begin{matrix}1\\2\\3\end{matrix}\right]

# %% [markdown]
# # Print and export the LaTeX equations for MSCommFitting

# %%
from sympy.printing.preview import preview
from IPython.display import display, Latex #, Image
from os import path
eqs = {
    'objective.png': r'$$\sum^{S,T,J}_{s,t,j} \left( EV^2_{s,t,j} \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)$$',
    'bioc_predicted_v_calculated.png': r'$E_{s,t,j}*EC = EB_{s,t,j}$',
    'diffc_biomass_variance.png': r'$EB_{s,t,j}-\sum^K_k \left( es_k*b_{t,j,k} \right) = EV_{s,t,j}$',
    'dbc_nonstationary.png': r'$b_{t,j,k} + \frac{\Delta t}{2}(g_{t,j,k}+g_{t+1,j,k}) + cvf_{t,j,k} - cvt_{t,j,k} = b_{t+1,j,k}$',
    'dbc_stationary.png': r'$b_{t,j,k} - \sum^{K,S}_{k,s} \left( es_{k,s}*cvf_{t,j,k} \right) + \sum^{K,S}_{k,s} \left( es_{k,s}*cvt_{t,j,k} \right) = b_{t+1,j,k}$',
    'cvc_transitions.png': r'$cvt_{t,j,k} \le bcv*b_{t,j,k} + cvmin$',
    'dcc_concentrations.png': r'$c_{t,j,i} + \frac{\Delta t}{2} \sum^K_k \left( n_{i,k}(g_{t,j,k}+g_{t+1,j,k}) \right) = c_{t+1,j,i}$'
}
for filename, eq in eqs.items():
    preview(eq, viewer='file', filename=filename, euler=False)
    display(Latex(eq))
# Out:
# $$\sum^{S,T,J}_{s,t,j} \left( EV^2_{s,t,j} \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)$$
# $E_{s,t,j}*EC = EB_{s,t,j}$
# $EB_{s,t,j}-\sum^K_k \left( es_k*b_{t,j,k} \right) = EV_{s,t,j}$
# $b_{t,j,k} + \frac{\Delta t}{2}(g_{t,j,k}+g_{t+1,j,k}) + cvf_{t,j,k} - cvt_{t,j,k} = b_{t+1,j,k}$
# $b_{t,j,k} - \sum^{K,S}_{k,s} \left( es_{k,s}*cvf_{t,j,k} \right) + \sum^{K,S}_{k,s} \left( es_{k,s}*cvt_{t,j,k} \right) = b_{t+1,j,k}$
# $cvt_{t,j,k} \le bcv*b_{t,j,k} + cvmin$
# $c_{t,j,i} + \frac{\Delta t}{2} \sum^K_k \left( n_{i,k}(g_{t,j,k}+g_{t+1,j,k}) \right) = c_{t+1,j,i}$

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_annotation(text=r'$E_{s,t,j}*EC = EB_{s,t,j}$')
fig.show()
fig.write_image('test.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       4 fig.add_annotation(text=r'$E_{s,t,j}*EC = EB_{s,t,j}$')
#       5 fig.show()
# ----> 6 fig.write_image('test.png')
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\basedatatypes.py:3829, in BaseFigure.write_image(self, *args, **kwargs)
#    3769 """
#    3770 Convert a figure to a static image and write it to a file or writeable
#    3771 object
#    (...)
#    3825 None
#    3826 """
#    3827 import plotly.io as pio
# -> 3829 return pio.write_image(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\plotly\io\_kaleido.py:267, in write_image(fig, file, format, scale, width, height, validate, engine)
#     251             raise ValueError(
#     252                 """
# ...

# %%
# from pnglatex import pnglatex
# %matplotlib inline

# # objective function
# pnglatex(r'\[\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)\]', 
#                   'objective_function.png')

from IPython.display import display, Latex, Image
import io
from PIL import Image, ImageChops
from matplotlib import pyplot
import pickle 
objective = Latex(r'\[\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)\]')
display(objective)
# png = objective._repr_png_()
# with open('output.png', 'wb') as out:
#     out.write(pickle.dumps(objective))
# print(dir(objective))

# plt = matplotlib.pyplot.plot(objective)
# buf = io.BytesIO()
def latex_to_png(tex):
    pyplot.rcParams.update({
        "text.usetex": True,
        "font.family": "sans-serif",
        "font.sans-serif": ["Helvetica"]})
    pyplot.axis('off')
    pyplot.text(0.05, 0.5, f'${tex}$', size=40)
    pyplot.savefig('output.png')
latex_to_png(r'\[\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)\]')
# for eq in [objective]:
#     display(eq)
# Out:
# \[\sum^{S}_{s} \left( \sum^{T,J}_{t,j} \left( EV^2_{s,t,j} \right)  \right) - \sum^{T,J,K}_{t,j,k} \left( cvct*cvt_{t,j,k} \right) - \sum^{T,J, K}_{t,j,k} \left( cvcf*cvf_{t,j,k} \right)\]
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\texmanager.py:233, in TexManager._run_checked_subprocess(self, command, tex, cwd)
#     232 try:
# --> 233     report = subprocess.check_output(
#     234         command, cwd=cwd if cwd is not None else self.texcache,
#     235         stderr=subprocess.STDOUT)
#     236 except FileNotFoundError as exc:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\subprocess.py:424, in check_output(timeout, *popenargs, **kwargs)
#     422     kwargs['input'] = empty
# --> 424 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# ...
